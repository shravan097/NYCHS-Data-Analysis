# %%
import sys
sys.path.append('..')
from datasets import *
import pandas as pd

# %%
df= get_SATScores()

# %%
df
# Out:
#         dbn num_of_sat_test_takers sat_critical_reading_avg_score  \
# 0    01M292                     29                            355
# 1    01M448                     91                            383
# 2    01M450                     70                            377
# 3    01M458                      7                            414
# 4    01M509                     44                            390
# 5    01M515                    112                            332
# 6    01M539                    159                            522
# 7    01M650                     18                            417
# 8    01M696                    130                            624
# 9    02M047                     16                            395
# 10   02M288                     62                            409
# 11   02M294                     53                            394
# 12   02M296                     58                            374
# ...
